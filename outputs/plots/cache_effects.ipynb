# %%
import os
import collections
import seaborn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#adj_kron
column_list = ['i0', 'i1', 'i2', 'i3', 'i4', 'i5', 'i6',
       'i7', 'i8', 'i9']
adj_rd_kron_times = []
for scale in range(10,22):
    filename = "/Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s"+ str(scale) + "_e8_pr.csv"
    print (filename)
    kron_time = pd.read_csv(filename)
    times = kron_time[column_list].sum(axis=1)
    adj_pr_time = np.mean(times.to_numpy())
    adj_rd_kron_times.append(adj_pr_time*1e-6)
#adj_rd_kron_times.append(196.0741889) #CIT
for scale in range(22,25):
    filename = "/Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s"+ str(scale) + "_e8_pr.csv"
    print (filename)
    kron_time = pd.read_csv(filename)
    times = kron_time[column_list].sum(axis=1)
    adj_pr_time = np.mean(times.to_numpy())
    adj_rd_kron_times.append(adj_pr_time*1e-6)
print(adj_rd_kron_times)
# Out:
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s10_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s11_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s12_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s13_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s14_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s15_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s16_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s17_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s18_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s19_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s20_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s21_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s22_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s23_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s24_e8_pr.csv
# [0.06670966666666667, 0.10476891999999999, 0.20817835999999998, 0.41862903999999995, 0.85071716, 1.7486554399999998, 3.60398752, 7.2082794, 15.207169519999999, 31.255220866666665, 65.7167235, 144.5511836, 312.5663366, 699.045168, 7731.718725]

# %%
#ekey_kron
column_list = ['i0', 'i1', 'i2', 'i3', 'i4', 'i5', 'i6',
       'i7', 'i8', 'i9']
ekey_rd_kron_times = []
for scale in range(10,21):
    filename = "/Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s"+ str(scale) + "_e8_pr.csv"
    print (filename)
    kron_time = pd.read_csv(filename)
    times = kron_time[column_list].sum(axis=1)
    ekey_pr_time = np.mean(times.to_numpy())
    ekey_rd_kron_times.append(ekey_pr_time*1e-6)
print(ekey_rd_kron_times)
# Out:
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s10_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s11_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s12_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s13_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s14_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s15_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s16_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s17_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s18_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s19_e8_pr.csv
# /Users/Puneet89/scratch/margraphita/outputs/benchmarks/ekey_rd_s20_e8_pr.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/2k/prv9ywh52sn57l626bl42pz40000gp/T/ipykernel_90347/4108443782.py in <module>
#       7     print (filename)
#       8     kron_time = pd.read_csv(filename)
# ----> 9     times = kron_time[column_list].sum(axis=1)
#      10     ekey_pr_time = np.mean(times.to_numpy())
#      11     ekey_rd_kron_times.append(ekey_pr_time*1e-6)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['i0', 'i1', 'i2', 'i3', 'i4', 'i5', 'i6', 'i7', 'i8', 'i9'], dtype='object')] are in the [columns]"

# %%
#std_kron
column_list = ['i0', 'i1', 'i2', 'i3', 'i4', 'i5', 'i6',
       'i7', 'i8', 'i9']
std_rd_kron_times = []
for scale in range(10,21):
    filename = "/Users/Puneet89/scratch/margraphita/outputs/benchmarks/std_rd_s"+ str(scale) + "_e8_pr.csv"
    print (filename)
    kron_time = pd.read_csv(filename)
    times = kron_time[column_list].sum(axis=1)
    std_pr_time = np.mean(times.to_numpy())
    std_rd_kron_times.append(std_pr_time*1e-6)

# for scale in range(22,25):
#     filename = "/Users/Puneet89/scratch/margraphita/outputs/benchmarks/adj_rd_s"+ str(scale) + "_e8_pr.csv"
#     print (filename)
#     kron_time = pd.read_csv(filename)
#     times = kron_time[column_list].sum(axis=1)
#     adj_pr_time = np.mean(times.to_numpy())
#     adj_rd_kron_times.append(adj_pr_time*1e-6)
print(std_rd_kron_times)

# %%
x = []
for i in range(10,22):
    x.append("s"+str(i))
# x.append("CIT")
for i in range(22,25):
    x.append("s"+str(i))
print (x)
print(len(adj_rd_kron_times))
adj_pr_line, = plt.plot(x, adj_rd_kron_times,marker=".", markersize=10)
adj_pr_line.set_label("AdjList")

plt.xlabel('Datasets')
plt.ylabel('Time (secs)')
plt.legend()
plt.savefig('/Users/Puneet89/Documents/rpe_doc/fig/cache.pdf', bbox_inches='tight')
# Out:
# ['s10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 's24']
# 15

# %%
from matplotlib import pyplot as plt

x_adj = ['s10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 's24']
x_stdadj = ['s10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20']

fig, ax = plt.subplots()
ax.plot(x_adj, adj_rd_kron_times, label='AdjList', marker=".", markersize=10)
ax.plot(x_stdadj, ekey_rd_kron_times, label='EdgeKey', marker="+", markersize=10)
ax.plot(x_stdadj, std_rd_kron_times, label='Std', marker="x", markersize=10)
legend = ax.legend()
plt.xlabel('Datasets')
plt.ylabel('Time (s)')
#plt.title('Comparison of the different prices')
plt.savefig('/Users/Puneet89/Documents/rpe_doc/fig/cache.pdf', bbox_inches='tight')

# %% [markdown]
# # Time Breakdown from MT insert

# %%
x_labels = np.array(['18_A','18_E','18_S','19_A','19_E','19_S','20_A','20_E','20_S','21_A','21_E','21_S','22_A','22_E','22_S','23_A','23_E','23_S'])
y_ter = np.array([117696, 117969, 117952, 251792, 252911, 251503, 534187, 534337, 535381, 1194444, 1183793, 1197416, 2532925, 2556050, 2596303, 5401967, 5317622, 5321285])
y_tei = np.array([177363, 179119, 179140, 323707, 329597, 326135, 817167, 842420, 818023, 1650685, 1650574, 1635362, 3536772, 3154351, 3109330, 6253805, 6527088, 6534660])
y_tnr = np.array([20219, 20390, 20432, 41064, 42152, 40942, 83669, 83535, 85415, 170356, 176269, 174572, 356975, 355147, 342527, 779529, 737959, 752939])
y_tni = np.array([78497, 30877, 16293, 151124, 65530, 29557, 433673, 113596, 72120, 731293, 247124, 133840, 1600506, 567067, 251488, 3165438, 1257882, 520798])

width=0.45
fig,ax = plt.subplots()

ax.bar(x_labels, y_ter, color='#716F81', label="Time to Read Edgelist")
ax.bar(x_labels, y_tei, color='#B97A95', bottom=y_ter, label = "Time to Insert Edges")
ax.bar(x_labels, y_tnr, color='#F6AE99', bottom=y_tei+y_ter, label = "Time to Read Nodes")
ax.bar(x_labels, y_tni, color='#F2E1C1', bottom=y_tnr+y_tei+y_ter, label = "Time to Insert Nodes")

ax.set_ylabel('Time (usecs)')
ax.set_xlabel('Scale Factors')
ax.set_title('Time breakdown for insertion')
ax.legend()
plt.xticks(rotation=45)
plt.savefig('/Users/Puneet89/Documents/huawei-graph-report/fig/time_breakdown_new.pdf', bbox_inches='tight')
